# %%
import csv
from time import sleep
from bs4 import BeautifulSoup
from new_listing_scrape import basically_a_con
from _pile import addresses, hdotp, new_pleasanton_short_link, nol


'''
returns every address from scrape of pages 1-21 of new pleasanton listings
'''


def pull_the_new_listings_address_only(base_url):
    # determine how many pages deep this will go
    r = basically_a_con(base_url)
    # set variable
    n_pages = determine_pages(r)
    
    
    # master list
    fly_out = []
    # make list of links to each page in the sub-domain
    pages = [base_url + '/' + str(_) for _ in range(1, n_pages)]
    # pull data from each of them
    for page in pages:
        # print(i)
        sleep(1)
        # define info hub
        response = basically_a_con(page)
        # url accessibility check
        if response is not None:
            # define content
            html = BeautifulSoup(response, hdotp)
            # define out-route
            _ = set()
            for ul in html.select(addresses):
                # 12 addresses (max seen)
                for info in ul.text.split('\n'):
                    # is it legit
                    if len(info) > 0:
                        # print(_)
                        # tag & bag
                        _.add(info.strip())
                    else:
                        print(f'possible error; len(info) == {len(info)}')
            # update
            fly_out.append(list(_))
    # touchdown
    return fly_out

# %%
def determine_pages(response):
    # url accessibility check
    if response is not None:
        # define content
        html = BeautifulSoup(response, hdotp)
        # define out-route
        _ = set()
        for ul in html.select(nol):
            # 12 addresses (max seen)
            for info in ul.text.split('\n'):
                # is it legit
                if len(info) > 0:
                    # tag & bag
                    _.add(info.strip())
        # storage
        numbers = set()
        # Viewing 1-12 of 251 listings (account for thousands , break on space)
        for _ in str(_).replace(',','').split(' '):
            # nice collection of numbers 
            for i in '0123456789':
                # you got any numbers, fam?
                if i in _:
                    # '1-12' , '251'
                    numbers.add(_)
        # call storage
        for i in list( numbers ):
            # determine '1-12' from '251'
            i = i.split('-')
            if len(i) == 1:
                # ['251']
                # how many listings are in the selection
                total = int(i.pop())
            else:
                # ['1','12']
                # how many listings are being displayed per page
                per_page = int(i.pop())
        # determine number of pages in view
        n_pages = int( total / per_page )
        # if number of listings doesn't evenly divide 
        if isinstance((total/per_page),float):
            # add an extra page to make sure we get em all
            n_pages += 1
    return n_pages

# %%
napa = 'https://loiscox.bhhsdrysdale.com/homes/for-sale/city-Napa/lat-38.195976-38.629822000000004/lon-_122.46959299999999-_122.108898/type-single%20family/dsort-cl'
sfo = 'https://loiscox.bhhsdrysdale.com/homes/for-sale/status-active/city-;San%20Francisco/dsort-n'

# %%
determine_pages(basically_a_con(new_pleasanton_short_link))
# Out:
# 23

# %%
new_active_listings_san_francisco_city = 
determine_pages(basically_a_con(new_active_listings_san_francisco_city))
# Out:
# 91

# %%
determine_pages(basically_a_con(napa))
# Out:
# 25

# %%
pull_the_new_pleasanton_listings(napa)
# Out:
# [['2641 PINE ST, NAPA, CA, 94558',
#   'Address Undisclosed',
#   '22085 COOMBSVILLE ROAD, NAPA, CA 94558',
#   '47 ROSEMONT CIR, NAPA, CA, 94558',
#   '1080 WOODEN VALLEY CROSS RD, NAPA, CA, 94558',
#   '3235 SODA CANYON RD, NAPA, CA, 94558',
#   '3100 OLD SONOMA RD, NAPA, CA, 94558',
#   '1105 MILTON RD, NAPA, CA, 94559',
#   '4086 JEFFERSON ST, NAPA, CA, 94558',
#   '2344 SILVERADO TRL, NAPA, CA, 94558',
#   '10 VINEYARD VIEW DR, NAPA, CA, 94558',
#   '3661 REDWOOD RD, NAPA, CA, 94558'],
#  ['1091 SIMPKINS RD, NAPA, CA, 94558',
#   '1043 ROSS CIR, NAPA, CA, 94558',
#   '3580 MONTICELLO RD, NAPA, CA, 94558',
#   '1291 MONTICELLO RD, NAPA, CA, 94558',
#   '1373 SODA CANYON RD, NAPA, CA, 94558',
#   '1069 SHADYBROOK LN, NAPA, CA, 94558',
#   '4044 SONOMA HWY #16, NAPA, CA, 94559',
#   '1103 MOUNT GEORGE AVE, NAPA, CA, 94558',
#   '1079 HEDGESIDE AVE, NAPA, CA, 94558',
#   '1159 GREEN VALLEY RD, NAPA, CA, 94558',
#   '5224 BIG RANCH RD, NAPA, CA, 94558',
#   '177 RIDGE DR, NAPA, CA, 94558'],
#  ['19 HUNTINGTON CT, NAPA, CA, 94558',
#   '161 CANYON PL, NAPA, CA, 94558',
#   '597 MONTECITO BLVD, NAPA, CA, 94559',
#   '460 MONTE VISTA CT, NAPA, CA, 94559',
#   '1060 RUTHERFORD RD, NAPA, CA, 94558',
#   '1105 HARDMAN AVE, NAPA, CA, 94558',
#   '1034 LORRAINE DR, NAPA, CA, 94558',
#   '1107 CASTLE OAKS DR, NAPA, CA, 94558',
#   '3430 WESTMINSTER CT, NAPA, CA, 94558',
#   '1228 HAGEN RD, NAPA, CA, 94558',
#   '5200 SILVERADO TRL, NAPA, CA, 94558',
#   '2 OLD COACH RD, NAPA, CA, 94558'],
#  ['1289 THOMPSON AVE, NAPA, CA, 94558',
#   '20 GARFIELD LN, NAPA, CA, 94558',
#   '651 MONTECITO BLVD, NAPA, CA, 94559',
#   '1045 SECOND AVE, NAPA, CA, 94558',
#   '3225 VICHY AVE, NAPA, CA, 94558',
#   '15 HUNTINGTON CT, NAPA, CA, 94558',
#   '5360 WASHINGTON ST, NAPA, CA, 94558',
#   '1237 TALL GRASS CT, NAPA, CA, 94558',
#   '1053 CUTTINGS WHARF RD, NAPA, CA, 94559',
#   '1130 CASTLE OAKS DR, NAPA, CA, 94558',
#   '1143 CASTLE OAKS DR, NAPA, CA, 94558',
#   '2670 ATLAS PEAK RD, NAPA, CA, 94558'],
#  ['3280 HAGEN RD, NAPA, CA, 94558',
#   '128 KREUZER LN, NAPA, CA, 94559',
#   '40 LONGHORN RIDGE RD, NAPA, CA, 94558',
#   '1874 SILVERADO TRL, NAPA, CA, 94558',
#   '310 ALTA MESA CIR, NAPA, CA, 94558',
#   '5360 WASHINGTON ST, NAPA, CA, 94558',
#   '1109 ATLAS PEAK RD, NAPA, CA, 94558',
#   '273 STONECREST DR, NAPA, CA, 94558',
#   '3050 OLD SONOMA RD, NAPA, CA, 94558',
#   '2057 MAIN ST, NAPA, CA, 94559',
#   '33 PASCALE CT, NAPA, CA, 94558',
#   '1065 SHADYBROOK LN, NAPA, CA, 94558'],
#  ['2089 1ST AVE, NAPA, CA, 94558',
#   '1696 MULLER DR, NAPA, CA, 94559',
#   '6265 DRY CREEK RD, NAPA, CA, 94558',
#   '1113 4TH AVE, NAPA, CA, 94559',
#   '1093 ROSS CIR, NAPA, CA, 94558',
#   '1533 G ST, NAPA, CA, 94559',
#   '320 ALTA MESA CIR, NAPA, CA, 94558',
#   '10 RENO CT, NAPA, CA, 94558',
#   '329 TROON DR, NAPA, CA, 94558',
#   '133 STONE MOUNTAIN CIR, NAPA, CA, 94558',
#   '30 HOLLY CT, NAPA, CA, 94558',
#   '359 SAINT ANDREWS DR, NAPA, CA, 94558'],
#  ['1691 KING AVE, NAPA, CA, 94559',
#   '3284 ATHERTON CIR, NAPA, CA, 94558',
#   '190 FRANKLIN ST, NAPA, CA, 94559',
#   '222 MONTE VISTA DR, NAPA, CA, 94559',
#   '1221 3RD AVE, NAPA, CA, 94558',
#   '1043 LA QUINTA CT, NAPA, CA, 94559',
#   '2111 PENNY LN, NAPA, CA, 94559',
#   '2335 W PARK AVE, NAPA, CA, 94558',
#   '663 BALBOA WAY, NAPA, CA, 94559',
#   '3111 REDWOOD RD, NAPA, CA, 94558',
#   '3180 VICHY AVE, NAPA, CA, 94558',
#   '1247 DARLING ST, NAPA, CA, 94558'],
#  ['1123 PENNYROYAL ST, NAPA, CA, 94559',
#   '6450 GORDON VALLEY RD, NAPA, CA, 94558',
#   '2205 SPENCER ST, NAPA, CA, 94559',
#   '3275 WOODEN VALLEY RD, NAPA, CA, 94558',
#   '2990 REDWOOD RD, NAPA, CA, 94558',
#   '1105 JUAREZ ST, NAPA, CA, 94559',
#   '1064 BERRY LN, NAPA, CA, 94558',
#   '1911 CAPELL VALLEY RD, NAPA, CA, 94558',
#   '1404 MEEK AVE, NAPA, CA, 94559',
#   '3501 WESTMINSTER WAY, NAPA, CA, 94558',
#   'Address Undisclosed'],
#  ['232 MERANO WAY, NAPA, CA, 94558',
#   '2679 REDWOOD RD, NAPA, CA, 94558',
#   '5 RAVENWOOD LN, NAPA, CA, 94558',
#   '4 SKYCREST WAY, NAPA, CA, 94558',
#   '2119 FIRST AVE, NAPA, CA, 94558',
#   '1536 JUANITA ST, NAPA, CA, 94559',
#   '2011 W F ST, NAPA, CA, 94558',
#   '2155 RANCH CT, NAPA, CA, 94558',
#   'Address Undisclosed',
#   '1294 CARRELL LN, NAPA, CA, 94558',
#   '2201 MOUNT VEEDER RD, NAPA, CA, 94558'],
#  ['710 CASSWALL ST, NAPA, CA, 94558',
#   '1222 DAFFODIL DR, NAPA, CA, 94558',
#   '3993 LUCERO ST, NAPA, CA, 94558',
#   '1962 YAJOME ST, NAPA, CA, 94559',
#   '5220 BIAVA AVE, NAPA, CA, 94558',
#   '61 CAPELL VALLEY CRST, NAPA, CA, 94558',
#   '223 OLD VINE WAY, NAPA, CA, 94558',
#   '31 S NEWPORT DR, NAPA, CA, 94559',
#   '1830 CAPELL CROSS RD, NAPA, CA, 94558',
#   '605 PATCHETT ST, NAPA, CA, 94559',
#   '1039 BIRKDALE DR, NAPA, CA, 94559',
#   '250 SILVERADO SPRINGS DR, NAPA, CA, 94558'],
#  ['1081 TAMARISK DR #A, NAPA, CA, 94559',
#   '3000 HAGEN RD, NAPA, CA, 94558',
#   '1580 EL CENTRO AVE, NAPA, CA, 94558',
#   '16 CHESAPEAKE CT, NAPA, CA, 94559',
#   '1137 LA PINTURA LN, NAPA, CA, 94558',
#   '22 SEA BREEZE CT, NAPA, CA, 94559',
#   '35 AUTUMN RUN WAY, NAPA, CA, 94558',
#   '2120 WEST PARK AVE, NAPA, CA, 94558',
#   '3181 TIFFANIE LN, NAPA, CA, 94558',
#   'Address Undisclosed',
#   '37 COVE CT, NAPA, CA, 94559',
#   '23 HAVEN WAY #NAPA, NAPA, CA, 94558'],
#  ['3319 BRITTANY CIR, NAPA, CA, 94558',
#   'Address Undisclosed',
#   '3247 TWIN OAKS DR, NAPA, CA, 94558',
#   '70 HAHNEMANN LN, NAPA, CA, 94558',
#   '1018 LITTLE ST, NAPA, CA, 94558',
#   '34 HAHNEMANN LN, NAPA, CA, 94558',
#   '1441 SPRUCE ST, NAPA, CA, 94559',
#   '2005 WILKINS AVE, NAPA, CA, 94559',
#   '87 JULIAN AVE, NAPA, CA, 94559',
#   '1018 OAKMONT CT, NAPA, CA, 94559',
#   '3 ROSEMONT CIR, NAPA, CA, 94558',
#   '22 LEXINGTON CT, NAPA, CA, 94559'],
#  ['78 CATANIA LN, NAPA, CA, 94558',
#   '1191 HAGEN RD, NAPA, CA, 94558',
#   '1117 HILTON AVE, NAPA, CA 94558',
#   '106 WILLOWBEND CT, NAPA, CA, 94559',
#   '930 CHELEBROOKE CT, NAPA, CA, 94558',
#   '5373 DRY CREEK RD, NAPA, CA, 94558',
#   '53 SAINT FRANCIS CIR, NAPA, CA, 94558',
#   '2 CASASSA CT, NAPA, CA, 94558',
#   '68 BLACK WALNUT LN, NAPA, CA, 94559',
#   '2442 ALLEGHENY DR, NAPA, CA, 94558',
#   '3366 LINDA MESA WAY, NAPA, CA, 94558',
#   '36 COOMBSVILLE RD, NAPA, CA, 94558'],
#  ['50 DICKERSON LN, NAPA, CA, 94558',
#   '2596 1ST ST #C/B, NAPA, CA, 94558',
#   '40 CULBERTSON CT, NAPA, CA, 94558',
#   '4105 PRIMROSE WAY, NAPA, CA, 94558',
#   '58 CULBERTSON CT, NAPA, CA, 94558',
#   '2059 LOCUST ST, NAPA, CA, 94559',
#   '2594 1ST ST #C/B, NAPA, CA, 94558',
#   '1025 HAGEN RD, NAPA, CA, 94558',
#   '1802 SEVILLE DR, NAPA, CA, 94559',
#   '36 AUTUMN CREEK CT, NAPA, CA, 94559',
#   '1108 PINEWOOD DR, NAPA, CA, 94558',
#   '3549 MEADOWBROOK DR, NAPA, CA, 94558'],
#  ['2439 WINE COUNTRY AVE, NAPA, CA, 94558',
#   '31 DICKERSON LN, NAPA, CA, 94558',
#   '33 EDGEFIELD CT, NAPA, CA, 94558',
#   '1441 A ST, NAPA, CA, 94559',
#   '2117 1ST AVE, NAPA, CA, 94558',
#   '4270 WINE COUNTRY CT, NAPA, CA, 94558',
#   '1015 HAGEN RD, NAPA, CA, 94558',
#   '1025 MATT DR, NAPA, CA, 94558',
#   '1159 BROADMOOR DR, NAPA, CA, 94558',
#   'Address Undisclosed',
#   '2496 CABERNET CT, NAPA, CA, 94558',
#   '4035 MAHER ST, NAPA, CA, 94558'],
#  ['3518 WHITE CLIFF CIR, NAPA, CA, 94558',
#   '3343 MACBETH ST, NAPA, CA, 94558',
#   '1002 TERRACE DR, NAPA, CA, 94559',
#   '361 MONROE ST, NAPA, CA, 94559',
#   '4025 FAIRFAX DR, NAPA, CA, 94558',
#   '2492 CABERNET CT, NAPA, CA, 94558',
#   '1036 STONEBRIDGE DR, NAPA, CA, 94558',
#   '2371 STONEHOUSE DR, NAPA, CA, 94558',
#   '4029 MAHER ST, NAPA, CA, 94558',
#   '4413 TANGLEWOOD WAY, NAPA, CA 94558',
#   '26 WINDSOR CT, NAPA, CA, 94558',
#   '4413 TANGLEWOOD WAY, NAPA, CA, 94558'],
#  ['3679 PARRETT AVE, NAPA, CA, 94558',
#   '1633 PEAR TREE LN, NAPA, CA, 94558',
#   '571 FOOTHILL BLVD, NAPA, CA, 94558',
#   '1226 IONE CT, NAPA, CA, 94558',
#   '1828 PINE ST, NAPA, CA, 94559',
#   '4238 PRESIDIO WAY, NAPA, CA, 94558',
#   '990 CENTRAL AVE, NAPA, CA 94558',
#   '4721 MONTICELLO RD, NAPA, CA, 94558',
#   '3257 MACFADDEN ST, NAPA, CA, 94558',
#   '2596 1ST ST #A, NAPA, CA, 94558',
#   '100 FRANKLIN ST, NAPA, CA, 94559',
#   '1019 CHARLSON WAY, NAPA, CA, 94558'],
#  ['2965 PINEWOOD DR, NAPA, CA, 94558',
#   '2594 FIRST ST #A, NAPA, CA, 94558',
#   '1831 SEVILLE DR, NAPA, CA, 94559',
#   '2343 BEACH ST, NAPA, CA, 94558',
#   '491 ROOSEVELT ST, NAPA, CA, 94558',
#   '1650 PEAR TREE LN, NAPA, CA, 94558',
#   '3297 MACBETH ST, NAPA, CA, 94558',
#   '1044 VON BRANDT ST, NAPA, CA, 94559',
#   '3006 HAGEN RD, NAPA, CA, 94558',
#   '1033 CLARK ST, NAPA, CA, 94559',
#   '3175 LAUREL ST, NAPA, CA, 94558',
#   '4030 ENCINA DR, NAPA, CA, 94558'],
#  ['1084 LINDA VISTA AVE, NAPA, CA, 94558',
#   '1507 KING AVE, NAPA, CA, 94559',
#   '1628 GEORGIA ST, NAPA, CA 94559',
#   '1628 GEORGIA ST, NAPA, CA, 94559',
#   '2980 LAUREL ST, NAPA, CA, 94558',
#   '1134 SYLVIA CT, NAPA, CA, 94559',
#   '1718 SEQUOIA ST, NAPA, CA, 94558',
#   '1157 LEGION AVE, NAPA, CA, 94559',
#   '3672 WILLIS DR, NAPA, CA, 94558',
#   '4071 BROWNS VALLEY RD, NAPA, CA, 94558',
#   '1906 LECAIR CT, NAPA, CA, 94559',
#   '1089 TAMARISK DR, NAPA, CA, 94559'],
#  ['2042 KAYWOODIE ST, NAPA, CA, 94558',
#   '3 CAPITOLA CT, NAPA, CA, 94559',
#   '567 FOSTER RD, NAPA, CA, 94558',
#   '221 COLLIER BLVD, NAPA, CA, 94558',
#   '115 COOKS CT, NAPA, CA, 94558',
#   '4393 PLASS DR, NAPA, CA, 94558',
#   '1632 YELLOWSTONE ST, NAPA, CA, 94558',
#   '1473 SUMNER AVE, NAPA, CA, 94558',
#   '1684 WISE DR, NAPA, CA, 94558',
#   '3604 HARKNESS ST, NAPA, CA, 94558',
#   '3800 OXFORD ST, NAPA, CA, 94558',
#   '3950 GLACIER DR, NAPA, CA, 94558'],
#  ['3062 STADIUM AVE, NAPA, CA, 94558',
#   'Address Undisclosed',
#   '3269 PIEDMONT AVE, NAPA, CA, 94558',
#   '3681 OXFORD ST, NAPA, CA, 94558',
#   '3261 MONTCLAIR AVE, NAPA, CA, 94558',
#   '3768 JEFFERSON ST, NAPA, CA, 94558',
#   '2625 HIDDEN VALLEY LN, NAPA, CA, 94558',
#   '1771 WOODEN VALLEY, NAPA, CA 94558',
#   '2750 WIMBLEDON ST, NAPA, CA, 94558',
#   '3620 IDLEWILD AVE, NAPA, CA, 94558',
#   '956 CAYETANO DR, NAPA, CA, 94559',
#   '2496 REDWOOD RD, NAPA, CA, 94558'],
#  ['1324 STEELE CANYON RD, NAPA, CA, 94558',
#   '2150 UNBRIDLED CT, NAPA, CA, 94559',
#   '2551 ELM ST, NAPA, CA, 94558',
#   '1040 BLUERIDGE DR, NAPA, CA, 94558',
#   '2077 SOMMER ST, NAPA, CA, 94559',
#   '2932 GRECO DR, NAPA, CA, 94558',
#   '2388 BARRY ST, NAPA, CA, 94559',
#   '2212 BERKS ST, NAPA, CA, 94558',
#   '1633 CAROL DR, NAPA, CA, 94558',
#   'Address Undisclosed',
#   '1627 LINCOLN AVE, NAPA, CA, 94558',
#   '1330 H ST, NAPA, CA, 94559'],
#  ['211 BERRYESSA DR, NAPA, CA, 94558',
#   '1149 RIMROCK DR, NAPA, CA, 94558',
#   'Address Undisclosed',
#   '1005 ARROYO LINDA CT, NAPA, CA, 94558',
#   '318 BLACK OAK LN, NAPA, CA, 94558',
#   '228 MANZANITA LN, NAPA, CA, 94558',
#   '2421 2ND ST, NAPA, CA, 94559',
#   '1325 STEELE CANYON RD, NAPA, CA, 94558',
#   '429 WOODHAVEN CT, NAPA, CA, 94558',
#   '2174 WILKINS AVE, NAPA, CA, 94559',
#   '111 HOMEWOOD AVE, NAPA, CA, 94558',
#   '1861 F ST, NAPA, CA, 94559'],
#  ['119 PARKVIEW LN, NAPA, CA, 94558',
#   '101 E CLEARWATER CT, NAPA, CA, 94558',
#   '1148 RIMROCK DR, NAPA, CA, 94558',
#   '4280 OLD SONOMA HIGHWAY RD #73E, NAPA, CA, 94559',
#   '1016 EASTRIDGE DR, NAPA, CA, 94558',
#   '1006 WESTRIDGE DR, NAPA, CA, 94558',
#   '410 RED ROCK LN, NAPA, CA, 94558',
#   '121 PARKVIEW LN, NAPA, CA, 94558',
#   '1123 RIMROCK DR, NAPA, CA, 94558',
#   '809 BAHIA VISTA CT, NAPA, CA, 94558',
#   '1148 RIMROCK DR, NAPA, CA 94558']]

# %%
one_listing_full = ".mdl-cell:nth-of-type(1) div.description, h2#show-address954107, h2:contains('3100 OLD SONOMA RD, NAPA, CA, 94558') + h3"

# %%
import csv
from time import sleep
from bs4 import BeautifulSoup
from new_listing_scrape import basically_a_con
from _pile import addresses, hdotp, new_pleasanton_short_link, nol


'''
returns every address from scrape of pages 1-21 of new pleasanton listings
'''


def pull_the_new_listings(base_url):
    # determine how many pages deep this will go
    r = basically_a_con(base_url)
    # set variable
    n_pages = determine_pages(r)
    
    
    # master list
    fly_out = []
    # make list of links to each page in the sub-domain
    pages = [base_url + '/' + str(_) for _ in range(1, n_pages)]
    # pull data from each of them
    for page in pages:
        # print(i)
        sleep(1)
        # define info hub
        response = basically_a_con(page)
        # url accessibility check
        if response is not None:
            # define content
            html = BeautifulSoup(response, hdotp)
            # define out-route
            _ = set()
            for ul in html.select(one_listing_full):
                # 12 addresses (max seen)
                for info in ul.text.split('\n'):
                    # is it legit
                    if len(info) > 0:
                        # print(_)
                        # tag & bag
                        _.add(info.strip())
                    else:
                        print(f'possible error; len(info) == {len(info)}')
            # update
            fly_out.append(list(_))
    # touchdown
    return fly_out

# %%
pull_the_new_listings(napa)
